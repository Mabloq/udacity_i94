# %% [markdown]
# # AIRPORT DATA EXPLORATION

# %%
import pandas as pd
import json

pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('/home/mabloq/airflow/data/airport-codes_csv.csv', sep=",")
df.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# ...

# %%
df.describe()
# Out:
#        elevation_ft
# count  48069.000000
# mean    1240.789677
# std     1602.363459
# min    -1266.000000
# 25%      205.000000
# 50%      718.000000
# 75%     1497.000000
# max    22000.000000

# %%
df.loc[df['iso_country'] == "US"]
# df.loc[df['iata_code'].str.contains('BA',na=False)]
# Out:
#       ident           type                                name  elevation_ft  \
# 0       00A       heliport                   Total Rf Heliport          11.0
# 1      00AA  small_airport                Aero B Ranch Airport        3435.0
# 2      00AK  small_airport                        Lowell Field         450.0
# 3      00AL  small_airport                        Epps Airpark         820.0
# 4      00AR         closed  Newport Hospital & Clinic Heliport         237.0
# ...     ...            ...                                 ...           ...
# 54574   Z91  small_airport                 Birch Creek Airport         450.0
# 54575   Z92  small_airport              Harsens Island Airport         578.0
# 54576   Z93  small_airport             Copper Center 2 Airport        1150.0
# 54577   Z95  small_airport                     Cibecue Airport        5037.0
# 54896   ZNC  small_airport                        Nyac Airport         460.0
#
# ...
